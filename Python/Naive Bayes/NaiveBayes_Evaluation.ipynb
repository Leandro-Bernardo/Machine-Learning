# %%
import pandas as pd
import numpy as np

# %%
metrics_folds = {
                'fold_0' : pd.read_csv(f'metrics_fold_0.csv'),
                'fold_1' : pd.read_csv(f'metrics_fold_1.csv'),
                'fold_2' : pd.read_csv(f'metrics_fold_2.csv'),
                'fold_3' : pd.read_csv(f'metrics_fold_3.csv'),
                'fold_4' : pd.read_csv(f'metrics_fold_4.csv'),
                }

metrics_folds.get('fold_0')
# Out:
#                            class  precision    recall  f1-score  support
# 0                     few_clouds   0.080645  0.015291  0.025707    654.0
# 1               scattered_clouds   0.164589  0.073579  0.101695    897.0
# 2                  broken_clouds   0.249201  0.254072  0.251613   1228.0
# 3                   sky_is_clear   0.333918  0.503527  0.401547   2268.0
# 4                overcast_clouds   0.161790  0.108796  0.130104    864.0
# 5                           mist   0.264438  0.403151  0.319383   1079.0
# 6                        drizzle   0.097561  0.088889  0.093023     45.0
# 7                  moderate_rain   0.028169  0.010753  0.015564    186.0
# 8        light_intensity_drizzle   0.000000  0.000000  0.000000     81.0
# 9                     light_rain   0.127976  0.108999  0.117728    789.0
# 10                           fog   0.207921  0.097674  0.132911    215.0
# 11                          haze   0.000000  0.000000  0.000000    138.0
# 12                    heavy_snow   0.000000  0.000000  0.000000     24.0
# 13       heavy_intensity_drizzle   0.000000  0.000000  0.000000      4.0
# 14          heavy_intensity_rain   0.054054  0.027027  0.036036     74.0
# 15           light_rain_and_snow   0.000000  0.000000  0.000000      2.0
# 16                          snow   0.000000  0.000000  0.000000     20.0
# 17                    light_snow   0.072727  0.103896  0.085561     77.0
# 18        proximity_thunderstorm   0.000000  0.000000  0.000000     22.0
# 19                  thunderstorm   0.000000  0.000000  0.000000     15.0
# 20        thunderstorm_with_rain   0.066667  0.250000  0.105263      4.0
# 21  thunderstorm_with_heavy_rain   0.000000  0.000000  0.000000      3.0
# 22  thunderstorm_with_light_rain   0.000000  0.000000  0.000000      7.0
# 23               very_heavy_rain   0.000000  0.000000  0.000000     16.0
# 24                          dust   0.000000  0.000000  0.000000      4.0
# 25                     micro avg   0.251295  0.250459  0.250876   8716.0
# 26                     macro avg   0.076386  0.081826  0.072645   8716.0
# 27                  weighted avg   0.212713  0.250459  0.220625   8716.0

# %%
'''
Micro Avg (Micro Average)
    É calculado agregando as contagens de verdadeiros positivos, falsos positivos e falsos negativos de todas as classes e, em seguida, calculando as métricas de precisão, recall e f1-score com base nesses totais agregados.
    É útil quando é desejado dar peso igual a todas as instâncias, independentemente da classe.


Macro Avg (Macro Average):
    O macro avg é calculado calculando as métricas de precisão, recall e f1-score separadamente para cada classe e, em seguida, tirando a média desses valores.
    Dá igual peso a todas as classes, independentemente de sua distribuição no conjunto de dados. Cada classe contribui com a mesma quantidade para as métricas de média.


Weighted Avg (Weighted Average):
    O weighted avg é semelhante ao macro avg, mas dá pesos diferentes a cada classe com base na proporção de amostras de cada classe no conjunto de dados.
    Pondera as métricas de acordo com o número de amostras de cada classe. Classes com mais amostras têm mais impacto nas métricas de média.
'''

# %%
evaluation = {}
for fold in metrics_folds.keys():
    evaluation[fold] = { 
                        'precision': {'mean': np.mean(metrics_folds.get(fold)['precision']), 'std': np.std(metrics_folds.get(fold)['precision'])},
                        'recall': {'mean': np.mean(metrics_folds.get(fold)['recall']), 'std': np.std(metrics_folds.get(fold)['recall'])},
                        'f1-score': {'mean': np.mean(metrics_folds.get(fold)['f1-score']), 'std': np.std(metrics_folds.get(fold)['f1-score'])} 
                         }

# %%
evaluation['fold_1']
# Out:
# {'precision': {'mean': 0.08925143856268457, 'std': 0.10528964554462117},
#  'recall': {'mean': 0.08014388549301774, 'std': 0.13027075119957618},
#  'f1-score': {'mean': 0.07629818695812167, 'std': 0.10730000772619784}}

# %%
compare = pd.DataFrame(columns = ['precision_mean','precision_std', 'recall_mean', 'recall_std','f1-score_mean','f1-score_std' ], index=['fold_0','fold_1','fold_2','fold_3','fold_4',])

for fold in evaluation:
    for metric in evaluation.get(fold).keys():
        compare.loc[fold, 'precision_mean'] = evaluation.get(fold).get('precision').get('mean')
        compare.loc[fold, 'precision_std'] = evaluation.get(fold).get('precision').get('std')

        compare.loc[fold, 'recall_mean'] = evaluation.get(fold).get('recall').get('mean')
        compare.loc[fold, 'recall_std'] = evaluation.get(fold).get('recall').get('std')
        
        compare.loc[fold, 'f1-score_mean'] = evaluation.get(fold).get('f1-score').get('mean')
        compare.loc[fold, 'f1-score_std'] = evaluation.get(fold).get('f1-score').get('std')

# %%
compare
# Out:
#        precision_mean precision_std recall_mean recall_std f1-score_mean  \
# fold_0       0.087502      0.101017    0.093871   0.131881      0.084296
# fold_1       0.089251       0.10529    0.080144   0.130271      0.076298
# fold_2       0.095466      0.107558      0.0867   0.147319      0.074858
# fold_3        0.10167      0.117285    0.102278   0.157646      0.095272
# fold_4       0.136717      0.203066     0.10761   0.167564      0.104777
#
#        f1-score_std
# fold_0     0.108978
# fold_1       0.1073
# fold_2     0.111125
# fold_3     0.127477
# fold_4     0.149181
