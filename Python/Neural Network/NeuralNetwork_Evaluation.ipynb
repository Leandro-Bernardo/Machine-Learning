# %%
import pandas as pd
import numpy as np

# %%
metrics_folds = {
                'fold_0' : pd.read_csv(f'metrics_fold_0.csv'),
                'fold_1' : pd.read_csv(f'metrics_fold_1.csv'),
                'fold_2' : pd.read_csv(f'metrics_fold_2.csv'),
                'fold_3' : pd.read_csv(f'metrics_fold_3.csv'),
                'fold_4' : pd.read_csv(f'metrics_fold_4.csv'),
                }

metrics_folds.get('fold_4')
# Out:
#                            class  precision    recall  f1-score  support
# 0            light_rain_and_snow   0.800000  0.333333  0.500000      3.0
# 1                     heavy_snow   0.000000  0.000000  0.000000     24.0
# 2                very_heavy_rain   0.000000  0.000000  0.000000     16.0
# 3                           dust   0.000000  0.000000  0.000000      5.0
# 4                           snow   0.000000  0.000000  0.000000     19.0
# 5           heavy_intensity_rain   0.000000  0.000000  0.000000     73.0
# 6                  broken_clouds   0.237213  0.260586  0.248351   1228.0
# 7   thunderstorm_with_heavy_rain   0.000000  0.000000  0.000000      3.0
# 8                  moderate_rain   0.125000  0.005348  0.010256    187.0
# 9                     few_clouds   0.201220  0.050536  0.080783    653.0
# 10                  thunderstorm   0.030303  0.071429  0.042553     14.0
# 11              scattered_clouds   0.235955  0.163880  0.193421    897.0
# 12               overcast_clouds   0.224000  0.097335  0.135703    863.0
# 13                    light_rain   0.165992  0.051965  0.079151    789.0
# 14                  sky_is_clear   0.379167  0.601587  0.465156   2269.0
# 15                    light_snow   0.103448  0.038961  0.056604     77.0
# 16                          haze   0.000000  0.000000  0.000000    138.0
# 17                          mist   0.311871  0.574074  0.404172   1080.0
# 18                           fog   0.088235  0.013889  0.024000    216.0
# 19                       drizzle   0.000000  0.000000  0.000000     44.0
# 20       heavy_intensity_drizzle   0.000000  0.000000  0.000000      4.0
# 21       light_intensity_drizzle   0.020833  0.012500  0.015625     80.0
# 22  thunderstorm_with_light_rain   0.000000  0.000000  0.000000      7.0
# 23        proximity_thunderstorm   0.024390  0.043478  0.031250     23.0
# 24        thunderstorm_with_rain   0.000000  0.000000  0.000000      4.0
# 25                     micro avg   0.300780  0.300711  0.300746   8716.0
# 26                     macro avg   0.125905  0.092756  0.091481   8716.0
# 27                  weighted avg   0.253766  0.300711  0.254504   8716.0

# %%
'''
Micro Avg (Micro Average)
    É calculado agregando as contagens de verdadeiros positivos, falsos positivos e falsos negativos de todas as classes e, em seguida, calculando as métricas de precisão, recall e f1-score com base nesses totais agregados.
    É útil quando é desejado dar peso igual a todas as instâncias, independentemente da classe.


Macro Avg (Macro Average):
    O macro avg é calculado calculando as métricas de precisão, recall e f1-score separadamente para cada classe e, em seguida, tirando a média desses valores.
    Dá igual peso a todas as classes, independentemente de sua distribuição no conjunto de dados. Cada classe contribui com a mesma quantidade para as métricas de média.


Weighted Avg (Weighted Average):
    O weighted avg é semelhante ao macro avg, mas dá pesos diferentes a cada classe com base na proporção de amostras de cada classe no conjunto de dados.
    Pondera as métricas de acordo com o número de amostras de cada classe. Classes com mais amostras têm mais impacto nas métricas de média.
'''
# Out:
# '\nMicro Avg (Micro Average)\n    É calculado agregando as contagens de verdadeiros positivos, falsos positivos e falsos negativos de todas as classes e, em seguida, calculando as métricas de precisão, recall e f1-score com base nesses totais agregados.\n    É útil quando é desejado dar peso igual a todas as instâncias, independentemente da classe.\n\n\nMacro Avg (Macro Average):\n    O macro avg é calculado calculando as métricas de precisão, recall e f1-score separadamente para cada classe e, em seguida, tirando a média desses valores.\n    Dá igual peso a todas as classes, independentemente de sua distribuição no conjunto de dados. Cada classe contribui com a mesma quantidade para as métricas de média.\n\n\nWeighted Avg (Weighted Average):\n    O weighted avg é semelhante ao macro avg, mas dá pesos diferentes a cada classe com base na proporção de amostras de cada classe no conjunto de dados.\n    Pondera as métricas de acordo com o número de amostras de cada classe. Classes com mais amostras têm mais impacto nas métricas de média.\n'

# %%
accuracy = pd.read_csv('accuracy.csv').reset_index().drop('index',axis=1)#.transpose().rename({0:'accuracy'},axis = 1)
accuracy.mean()
# Out:
# accuracy    0.212829
# dtype: float64

# %%
evaluation = {}
for fold in metrics_folds.keys():
    evaluation[fold] = { 
                        'precision': {'mean': np.mean(metrics_folds.get(fold)['precision']), 'std': np.std(metrics_folds.get(fold)['precision'])},
                        'recall': {'mean': np.mean(metrics_folds.get(fold)['recall']), 'std': np.std(metrics_folds.get(fold)['recall'])},
                        'f1-score': {'mean': np.mean(metrics_folds.get(fold)['f1-score']), 'std': np.std(metrics_folds.get(fold)['f1-score'])} 
                         }

# %%
evaluation['fold_1']
# Out:
# {'precision': {'mean': 0.0696028686270627, 'std': 0.11183588969344546},
#  'recall': {'mean': 0.07605091390836104, 'std': 0.11848521382812759},
#  'f1-score': {'mean': 0.04795003764730244, 'std': 0.06319020217861634}}

# %%
compare = pd.DataFrame(columns = ['accuracy', 'precision', 'recall','f1-score',], index=['fold_0','fold_1','fold_2','fold_3','fold_4'])
compare['accuracy'] = accuracy

for fold in evaluation:
    for metric in evaluation.get(fold).keys():
        compare.loc[fold, 'precision'] = evaluation.get(fold).get('precision').get('mean')

        compare.loc[fold, 'recall'] = evaluation.get(fold).get('recall').get('mean')
        
        compare.loc[fold, 'f1-score'] = evaluation.get(fold).get('f1-score').get('mean')

compare.loc['mean','accuracy'] = compare['accuracy'].mean()
compare.loc['mean','precision'] = compare['precision'].mean()
compare.loc['mean','recall'] = compare['recall'].mean()
compare.loc['mean','f1-score'] = compare['f1-score'].mean()

compare
# Out:
#         accuracy precision    recall  f1-score
# fold_0       NaN  0.032059  0.103125  0.016483
# fold_1       NaN  0.069603  0.076051   0.04795
# fold_2       NaN  0.116732  0.080266   0.07864
# fold_3       NaN   0.10167  0.102278  0.095272
# fold_4       NaN  0.129574   0.10761  0.104777
# mean         NaN  0.089928  0.093866  0.068624
